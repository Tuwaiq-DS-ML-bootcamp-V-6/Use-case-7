# %% [markdown]
# ## Import Libraries

# %%
# To ignore warnings
import warnings
warnings.filterwarnings("ignore")
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import zscore
from sklearn.preprocessing import LabelEncoder

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, f1_score


# %matplotlib inline

# %% [markdown]
# ## Load the Data

# %%
df = pd.read_csv("cleaned/clean_data.csv")

# %%
df.info()
print(df.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10754 entries, 0 to 10753
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   team                 10754 non-null  object
#  1   name                 10754 non-null  object
#  2   position             10754 non-null  object
#  3   height               10754 non-null  float64
#  4   age                  10754 non-null  float64
#  5   appearance           10754 non-null  int64
#  6   goals                10754 non-null  float64
#  7   assists              10754 non-null  float64
#  8   yellow cards         10754 non-null  float64
#  9   second yellow cards  10754 non-null  float64
#  10  red cards            10754 non-null  float64
#  11  goals conceded       10754 non-null  float64
#  12  clean sheets         10754 non-null  float64
#  13  minutes played       10754 non-null  int64
#  14  days_injured         10754 non-null  int64
#  15  games_injured        10754 non-null  int64
#  16  award                10754 non-null  int64
#  17  current_value        10754 non-null  int64
#  18  highest_value        10754 non-null  int64
#  19  position_encoded     10754 non-null  int64
#  20  winger               10754 non-null  int64
# dtypes: float64(9), int64(9), object(3)
# memory usage: 1.7+ MB
# (10754, 21)

# %%
df["position_encoded"].value_counts()
# Out:
# position_encoded
# 2    3528
# 3    3095
# 4    2902
# 1    1229
# Name: count, dtype: int64

# %%
df["position"].value_counts()
# Out:
# position
# Defender Centre-Back          1821
# Attack Centre-Forward         1353
# Goalkeeper                    1229
# midfield-CentralMidfield      1149
# midfield-DefensiveMidfield     900
# Defender Right-Back            867
# Defender Left-Back             807
# midfield-AttackingMidfield     769
# Attack-RightWinger             717
# Attack-LeftWinger              714
# midfield-RightMidfield         102
# midfield-LeftMidfield          100
# midfield                        75
# Attack-SecondStriker            65
# Attack                          53
# Defender                        33
# Name: count, dtype: int64

# %%
df.head(2)
# Out:
#                 team          name    position  height   age  appearance  \
# 0  Manchester United  David de Gea  Goalkeeper   189.0  32.0         104
# 1  Manchester United  Jack Butland  Goalkeeper   196.0  30.0          15
#
#    goals  assists  yellow cards  second yellow cards  ...  goals conceded  \
# 0    0.0      0.0      0.009585                  0.0  ...        1.217252
# 1    0.0      0.0      0.069018                  0.0  ...        1.242331
#
#    clean sheets  minutes played  days_injured  games_injured  award  \
# 0      0.335463            9390            42              5     13
# 1      0.207055            1304           510             58      1
#
#    current_value  highest_value  position_encoded  winger
# 0       15000000       70000000                 1       0
# 1        1500000       22000000                 1       0
#
# [2 rows x 21 columns]

# %% [markdown]
# ## Preprocess the Data

# %% [markdown]
# #### 1. Simple EDA + Data Quality checking

# %% [markdown]
# <p style="color:blue">We have already conducted the EDA in EDA NoteBook</p>

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [team, name, position, height, age, appearance, goals, assists, yellow cards, second yellow cards, red cards, goals conceded, clean sheets, minutes played, days_injured, games_injured, award, current_value, highest_value, position_encoded, winger]
# Index: []
#
# [0 rows x 21 columns]

# %%
df.dtypes
# Out:
# team                    object
# name                    object
# position                object
# height                 float64
# age                    float64
# appearance               int64
# goals                  float64
# assists                float64
# yellow cards           float64
# second yellow cards    float64
# red cards              float64
# goals conceded         float64
# clean sheets           float64
# minutes played           int64
# days_injured             int64
# games_injured            int64
# award                    int64
# current_value            int64
# highest_value            int64
# position_encoded         int64
# winger                   int64
# dtype: object

# %%
# temp = {1: "Goalkeeper" , 2: "Defender", 3: "midfield", 4: "Attack"}
# df["position_encoded"] = df["position_encoded"].map(lambda x: temp[x])

# %%
df["position_encoded"]
# Out:
# 0        1
# 1        1
# 2        1
# 3        2
# 4        2
#         ..
# 10749    4
# 10750    4
# 10751    4
# 10752    4
# 10753    4
# Name: position_encoded, Length: 10754, dtype: int64

# %%
# df = df.drop("position", axis=1)

# %%
# df = df.rename(columns={"position_encoded" : "position"})

# %%
df.dtypes
# Out:
# team                    object
# name                    object
# position                object
# height                 float64
# age                    float64
# appearance               int64
# goals                  float64
# assists                float64
# yellow cards           float64
# second yellow cards    float64
# red cards              float64
# goals conceded         float64
# clean sheets           float64
# minutes played           int64
# days_injured             int64
# games_injured            int64
# award                    int64
# current_value            int64
# highest_value            int64
# position_encoded         int64
# winger                   int64
# dtype: object

# %%
# df.drop(, axis=1, inplace=True)

# %%
df.drop(["position","team","name"], axis=1, inplace=True)
# select features columns
categorical_features = list(df.select_dtypes(object).columns)
numeric_features = list(df.select_dtypes('number'))

# remove encoded columns


# removing this increased the r2 score but idk of this is luck (need more checking)
numeric_features.remove("highest_value")

# remove true value column
# categorical_features.remove('position_encoded')
# categorical_features.remove('team')

print(categorical_features)
print(numeric_features)
# Out:
# ['team']
# ['height', 'age', 'appearance', 'goals', 'assists', 'yellow cards', 'second yellow cards', 'red cards', 'goals conceded', 'clean sheets', 'minutes played', 'days_injured', 'games_injured', 'award', 'current_value', 'position_encoded']

# %%
# categorical_features.remove('position')

# %%
for i in categorical_features:
    print (df[i].value_counts())
# Out:
# team
# Daejeon Hana Citizen      46
# Jeonbuk Hyundai Motors    46
# FC Seoul                  45
# Gangwon FC                43
# Daegu FC                  42
#                           ..
# FC Barcelona              22
# Atlético de Madrid        22
# CA Osasuna                22
# Hatayspor                 12
# Gaziantep FK               6
# Name: count, Length: 374, dtype: int64

# %%
# all good for categorical data

# %%
# from our EDA we know that we have too many normal outliers

# %%
def plot_outliers(df: pd.DataFrame, features: list[str]) -> None:
    """
    Plots boxplots to show outliers for specified features in a DataFrame.
    
    param df: pd.DataFrame
    param features: list[str]
    
    return: None
    """
    # determine the number of rows needed for subplots
    n_rows: int = (len(features) + 2) // 3
    
    # create figure for subplots
    plt.figure(figsize=(15, 10))
    
    # plot each feature as a boxplot to show outliers
    for i, column in enumerate(features, 1):
        # add subplot
        plt.subplot(n_rows, 3, i)
        
        # create boxplot
        sns.boxplot(x=df[column])
        
        # set plot title and labels
        plt.title(f'{column.capitalize()} Distribution')
        plt.xlabel('')
        
        # add space between plots for clarity
        plt.subplots_adjust(hspace=0.85)
    
    # show plots
    plt.show()
    
plot_outliers(df, numeric_features)

# %%
# here we can see that there is many outliers and in our case 
# the Linear Regression is sensitive to outliers so we need a way to deal with the outlier, here are some:
# Z-Score
# IQR
# we will be using IQR

# %%
def remove_outliers_iqr(data: pd.DataFrame, columns: list[str]) -> pd.DataFrame:
    """
    Removes outliers from specified columns in a DataFrame using the IQR method.
    
    param data: pd.DataFrame
    param columns: list[str]
    
    return: pd.DataFrame
    """
    # iterate over each column to remove outliers
    for column in columns:
        # calculate Q1 (25th percentile) and Q3 (75th percentile)
        Q1 = data[column].quantile(0.25)
        Q3 = data[column].quantile(0.75)
        
        # calculate IQR (Interquartile Range)
        IQR = Q3 - Q1
        
        # define lower and upper bounds for outliers
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        
        # filter out outliers
        data = data[(data[column] >= lower_bound) & (data[column] <= upper_bound)]
    
    return data

# %%
def remove_outliers_zscore(df: pd.DataFrame, columns: list[str], threshold: float = 3.0) -> pd.DataFrame:
    """
    Removes outliers from specified columns in a DataFrame using the Z-score method.
    
    param df: pd.DataFrame - The input data.
    param columns: list[str] - The list of columns to check for outliers.
    param threshold: float - The Z-score threshold for identifying outliers.
    
    return: pd.DataFrame - The DataFrame with outliers removed.
    """
    # calculate Z-scores
    z_scores = np.abs(df[columns].apply(zscore))

    # filter out outliers
    filtered_df = df[(z_scores < threshold).all(axis=1)]
    
    return filtered_df

# %%
# filter outlier
filtered_data = remove_outliers_zscore(df, numeric_features, 3)

# plot to compare
plot_outliers(filtered_data, numeric_features)
print(f"Original vs IQR: {df.shape} vs {filtered_data.shape} ")
# Out:
# Original vs IQR: (10754, 18) vs (9369, 18)

# %%
# here we can see that the outliers are better by visualization (some data are too small need check)

# %% [markdown]
# #### 2. Feature engineering

# %% [markdown]
# 1. Feature scaling
# 2. Aggregation
# 3. One hot coding

# %%
# here we just change the df
# df = filtered_data.copy()

# %%
df.head(2)
# Out:
#                 team  height   age  appearance  goals  assists  yellow cards  \
# 0  Manchester United   189.0  32.0         104    0.0      0.0      0.009585
# 1  Manchester United   196.0  30.0          15    0.0      0.0      0.069018
#
#    second yellow cards  red cards  goals conceded  clean sheets  \
# 0                  0.0        0.0        1.217252      0.335463
# 1                  0.0        0.0        1.242331      0.207055
#
#    minutes played  days_injured  games_injured  award  current_value  \
# 0            9390            42              5     13       15000000
# 1            1304           510             58      1        1500000
#
#    highest_value  position_encoded
# 0       70000000                 1
# 1       22000000                 1

# %%
categorical_features
# Out:
# ['team']

# %%
# # one hot coding
# df = pd.get_dummies(df, columns=categorical_features)

# %%
df.columns
# Out:
# Index(['team', 'height', 'age', 'appearance', 'goals', 'assists',
#        'yellow cards', 'second yellow cards', 'red cards', 'goals conceded',
#        'clean sheets', 'minutes played', 'days_injured', 'games_injured',
#        'award', 'current_value', 'highest_value', 'position_encoded'],
#       dtype='object')

# %%
display(df.head(2))
df.shape
# Out:
#                 team  height   age  appearance  goals  assists  yellow cards  \
# 0  Manchester United   189.0  32.0         104    0.0      0.0      0.009585
# 1  Manchester United   196.0  30.0          15    0.0      0.0      0.069018
#
#    second yellow cards  red cards  goals conceded  clean sheets  \
# 0                  0.0        0.0        1.217252      0.335463
# 1                  0.0        0.0        1.242331      0.207055
#
#    minutes played  days_injured  games_injured  award  current_value  \
# 0            9390            42              5     13       15000000
# 1            1304           510             58      1        1500000
#
#    highest_value  position_encoded
# 0       70000000                 1
# 1       22000000                 1
# (10754, 18)

# %% [markdown]
# #### 3. Feature selection

# %%
plt.figure(figsize=(15, 10))
sns.heatmap(round(df[numeric_features].corr(),3), annot=True)
plt.title('Correlation Matrix')
plt.show()

# %%
df.columns
# Out:
# Index(['team', 'height', 'age', 'appearance', 'goals', 'assists',
#        'yellow cards', 'second yellow cards', 'red cards', 'goals conceded',
#        'clean sheets', 'minutes played', 'days_injured', 'games_injured',
#        'award', 'current_value', 'highest_value', 'position_encoded'],
#       dtype='object')

# %%
# encoder = LabelEncoder()
# df['position'] = encoder.fit_transform(df['position_encoded'])

# %%
df[numeric_features].head(2)
# Out:
#    height   age  appearance  goals  assists  yellow cards  \
# 0   189.0  32.0         104    0.0      0.0      0.009585
# 1   196.0  30.0          15    0.0      0.0      0.069018
#
#    second yellow cards  red cards  goals conceded  clean sheets  \
# 0                  0.0        0.0        1.217252      0.335463
# 1                  0.0        0.0        1.242331      0.207055
#
#    minutes played  days_injured  games_injured  award  current_value  \
# 0            9390            42              5     13       15000000
# 1            1304           510             58      1        1500000
#
#    position_encoded
# 0                 1
# 1                 1

# %%
df.select_dtypes('number').dtypes
# Out:
# height                 float64
# age                    float64
# appearance               int64
# goals                  float64
# assists                float64
# yellow cards           float64
# second yellow cards    float64
# red cards              float64
# goals conceded         float64
# clean sheets           float64
# minutes played           int64
# days_injured             int64
# games_injured            int64
# award                    int64
# current_value            int64
# highest_value            int64
# position_encoded         int64
# dtype: object

# %%
df['position_encoded'].value_counts()
# Out:
# position_encoded
# 2    3528
# 3    3095
# 4    2902
# 1    1229
# Name: count, dtype: int64

# %%
correlation = df.corr(numeric_only=True)
# print(correlation['position'].sort_values(ascending=False).head(10))
# correlation = df.corr(numeric_only=True)
# print(correlation['Price'].sort_values(ascending=False))
print(correlation['position_encoded'].sort_values(ascending=False))
# Out:
# position_encoded       1.000000
# goals                  0.434600
# assists                0.324714
# appearance             0.129357
# highest_value          0.101053
# current_value          0.085154
# yellow cards           0.077185
# award                  0.029111
# games_injured          0.019375
# days_injured           0.013889
# second yellow cards    0.005766
# red cards              0.004614
# minutes played        -0.039969
# clean sheets          -0.084334
# age                   -0.107469
# height                -0.378333
# goals conceded        -0.517020
# Name: position_encoded, dtype: float64

# %%
correlation
# Out:
#                        height       age  appearance     goals   assists  \
# height               1.000000  0.063652    0.060641 -0.055962 -0.202441
# age                  0.063652  1.000000    0.139846 -0.034805 -0.024156
# appearance           0.060641  0.139846    1.000000  0.131469  0.157186
# goals               -0.055962 -0.034805    0.131469  1.000000  0.218266
# assists             -0.202441 -0.024156    0.157186  0.218266  1.000000
# yellow cards        -0.037974  0.007085   -0.023092 -0.012826 -0.004430
# second yellow cards -0.005112  0.015529   -0.007436 -0.013974  0.019551
# red cards           -0.005693  0.003074   -0.024514 -0.013940 -0.013189
# goals conceded       0.333092  0.083343   -0.101384 -0.158107 -0.180607
# clean sheets         0.044366  0.039064   -0.032515 -0.025811 -0.029460
# minutes played       0.132887  0.169020    0.945365  0.050863  0.081136
# days_injured         0.059392  0.324267    0.127369  0.037527  0.039431
# games_injured        0.054902  0.343029    0.147528  0.041696  0.049383
# award                0.013976  0.363478    0.222139  0.099617  0.091569
# current_value        0.040535 -0.050156    0.419656  0.121574  0.137415
# highest_value        0.036776  0.123468    0.418394  0.129037  0.145407
# position_encoded    -0.378333 -0.107469    0.129357  0.434600  0.324714
#
#                      yellow cards  second yellow cards  red cards  \
# height                  -0.037974            -0.005112  -0.005693
# age                      0.007085             0.015529   0.003074
# appearance              -0.023092            -0.007436  -0.024514
# goals                   -0.012826            -0.013974  -0.013940
# assists                 -0.004430             0.019551  -0.013189
# yellow cards             1.000000             0.028739  -0.003007
# second yellow cards      0.028739             1.000000  -0.002562
# red cards               -0.003007            -0.002562   1.000000
# goals conceded          -0.093675            -0.045840  -0.004584
# clean sheets            -0.017122            -0.006770  -0.001778
# minutes played          -0.039652            -0.010411  -0.024402
# days_injured             0.011461             0.003772  -0.003650
# games_injured            0.012892             0.007090  -0.004764
# award                   -0.009052            -0.015231  -0.007886
# current_value           -0.011766            -0.013889  -0.010171
# highest_value           -0.009772            -0.014155  -0.007257
# position_encoded         0.077185             0.005766   0.004614
#
#                      goals conceded  clean sheets  minutes played  \
# height                     0.333092      0.044366        0.132887
# age                        0.083343      0.039064        0.169020
# appearance                -0.101384     -0.032515        0.945365
# goals                     -0.158107     -0.025811        0.050863
# assists                   -0.180607     -0.029460        0.081136
# yellow cards              -0.093675     -0.017122       -0.039652
# second yellow cards       -0.045840     -0.006770       -0.010411
# red cards                 -0.004584     -0.001778       -0.024402
# goals conceded             1.000000      0.067466       -0.004267
# clean sheets               0.067466      1.000000       -0.020190
# minutes played            -0.004267     -0.020190        1.000000
# days_injured              -0.030926      0.001275        0.107582
# games_injured             -0.042140      0.005611        0.123674
# award                     -0.011520      0.002996        0.214550
# current_value             -0.063529     -0.011684        0.420542
# highest_value             -0.061183     -0.008302        0.399389
# position_encoded          -0.517020     -0.084334       -0.039969
#
#                      days_injured  games_injured     award  current_value  \
# height                   0.059392       0.054902  0.013976       0.040535
# age                      0.324267       0.343029  0.363478      -0.050156
# appearance               0.127369       0.147528  0.222139       0.419656
# goals                    0.037527       0.041696  0.099617       0.121574
# assists                  0.039431       0.049383  0.091569       0.137415
# yellow cards             0.011461       0.012892 -0.009052      -0.011766
# second yellow cards      0.003772       0.007090 -0.015231      -0.013889
# red cards               -0.003650      -0.004764 -0.007886      -0.010171
# goals conceded          -0.030926      -0.042140 -0.011520      -0.063529
# clean sheets             0.001275       0.005611  0.002996      -0.011684
# minutes played           0.107582       0.123674  0.214550       0.420542
# days_injured             1.000000       0.954173  0.255124       0.107686
# games_injured            0.954173       1.000000  0.308460       0.135654
# award                    0.255124       0.308460  1.000000       0.300454
# current_value            0.107686       0.135654  0.300454       1.000000
# highest_value            0.234352       0.285244  0.528641       0.834553
# position_encoded         0.013889       0.019375  0.029111       0.085154
#
#                      highest_value  position_encoded
# height                    0.036776         -0.378333
# age                       0.123468         -0.107469
# appearance                0.418394          0.129357
# goals                     0.129037          0.434600
# assists                   0.145407          0.324714
# yellow cards             -0.009772          0.077185
# second yellow cards      -0.014155          0.005766
# red cards                -0.007257          0.004614
# goals conceded           -0.061183         -0.517020
# clean sheets             -0.008302         -0.084334
# minutes played            0.399389         -0.039969
# days_injured              0.234352          0.013889
# games_injured             0.285244          0.019375
# award                     0.528641          0.029111
# current_value             0.834553          0.085154
# highest_value             1.000000          0.101053
# position_encoded          0.101053          1.000000

# %%
# Set the correlation threshold
threshold = 0.03  # You can change this value based on your requirement

# Filter the correlations
# We use `abs()` for absolute value to consider both strong positive and negative correlations
selected_features = correlation[abs(correlation['position_encoded']) > threshold]['position_encoded'].index
selected_features
# Out:
# Index(['height', 'age', 'appearance', 'goals', 'assists', 'yellow cards',
#        'goals conceded', 'clean sheets', 'minutes played', 'current_value',
#        'highest_value', 'position_encoded'],
#       dtype='object')

# %%
df[selected_features]
# Out:
#            height   age  appearance     goals   assists  yellow cards  \
# 0      189.000000  32.0         104  0.000000  0.000000      0.009585
# 1      196.000000  30.0          15  0.000000  0.000000      0.069018
# 2      188.000000  37.0           4  0.000000  0.000000      0.000000
# 3      175.000000  25.0          82  0.028090  0.056180      0.224719
# 4      191.000000  30.0          63  0.017889  0.017889      0.053667
# ...           ...   ...         ...       ...       ...           ...
# 10749  181.240353  20.0          16  0.175953  0.087977      0.263930
# 10750  190.000000  24.0          26  0.372671  0.186335      0.186335
# 10751  181.240353  19.0          20  0.375000  0.000000      0.187500
# 10752  181.240353  20.0          17  0.312139  0.104046      0.000000
# 10753  170.000000  18.0          21  0.000000  0.000000      0.086042
#
#        goals conceded  clean sheets  minutes played  current_value  \
# 0            1.217252      0.335463            9390       15000000
# 1            1.242331      0.207055            1304        1500000
# 2            0.616438      0.924658             292         600000
# 3            0.000000      0.000000            6408       50000000
# 4            0.000000      0.000000            5031       40000000
# ...               ...           ...             ...            ...
# 10749        0.000000      0.000000            1023          75000
# 10750        0.000000      0.000000            1449         300000
# 10751        0.000000      0.000000             960          50000
# 10752        0.000000      0.000000             865          50000
# 10753        0.000000      0.000000            1046          25000
#
#        highest_value  position_encoded
# 0           70000000                 1
# 1           22000000                 1
# 2            6000000                 1
# 3           50000000                 2
# 4           80000000                 2
# ...              ...               ...
# 10749          75000                 4
# 10750         300000                 4
# 10751          50000                 4
# 10752          50000                 4
# 10753          25000                 4
#
# [10754 rows x 12 columns]

# %% [markdown]
# #### 4. Prepare train and test data

# %%
# Prepare data
X = df[selected_features].drop(["position_encoded"], axis=1)
y = df['position_encoded']
# label = df["position"]

# %%
df.head(2)
# Out:
#                 team  height   age  appearance  goals  assists  yellow cards  \
# 0  Manchester United   189.0  32.0         104    0.0      0.0      0.009585
# 1  Manchester United   196.0  30.0          15    0.0      0.0      0.069018
#
#    second yellow cards  red cards  goals conceded  clean sheets  \
# 0                  0.0        0.0        1.217252      0.335463
# 1                  0.0        0.0        1.242331      0.207055
#
#    minutes played  days_injured  games_injured  award  current_value  \
# 0            9390            42              5     13       15000000
# 1            1304           510             58      1        1500000
#
#    highest_value  position_encoded
# 0       70000000                 1
# 1       22000000                 1

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 42, test_size=.2)

# scale the data
scaler = StandardScaler()
scaler.fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# ## Buliding the Model

# %%
# create models
model = LogisticRegression()
# model_lasso  = Ridge()
# model_ridge = Lasso()

# %% [markdown]
# ## Train the Model

# %%
# fit the model (train)
model.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# ## Test the Model

# %%
y_pred = model.predict(X_test_scaled)

# %% [markdown]
# ## Interpretation of the Model

# %% [markdown]
# ### Model 1

# %%
for i in range(0, model.coef_.shape[0]):
    coeff_df = pd.DataFrame(model.coef_[i],X.columns,columns=['Coefficient'])
    display(i, coeff_df.sort_values(by="Coefficient", ascending=False))
# Out:
# 0
#                 Coefficient
# goals conceded     4.877699
# clean sheets       2.677133
# height             1.326826
# current_value      0.401138
# age                0.328832
# minutes played     0.321710
# highest_value     -0.261868
# yellow cards      -1.002638
# assists           -1.165645
# goals             -1.807247
# appearance        -3.960536
# 1
#                 Coefficient
# minutes played     1.870338
# assists            0.249447
# yellow cards       0.234244
# highest_value      0.078009
# height            -0.002372
# age               -0.030828
# current_value     -0.230874
# appearance        -0.396623
# goals             -0.859990
# clean sheets      -1.393357
# goals conceded    -2.544928
# 2
#                 Coefficient
# appearance         1.713574
# goals              0.715644
# assists            0.400547
# yellow cards       0.375059
# highest_value      0.093024
# current_value     -0.077480
# age               -0.185075
# minutes played    -0.432982
# height            -0.711091
# clean sheets      -0.877408
# goals conceded    -1.583457
# 3
#                 Coefficient
# appearance         2.643585
# goals              1.951593
# assists            0.515651
# yellow cards       0.393335
# highest_value      0.090835
# current_value     -0.092784
# age               -0.112930
# clean sheets      -0.406369
# height            -0.613364
# goals conceded    -0.749315
# minutes played    -1.759066

# %%
print(f"Intercept: \ny = mx + ({model.intercept_})")
# Out:
# Intercept:
# y = mx + ([-5.77311238  1.59180009  2.18214801  1.99916428])

# %% [markdown]
# ## Evaluating the Model

# %% [markdown]
# ### Model 1

# %%
# our benchmark model
base_model = round(df['position_encoded'].value_counts()[1]/df.shape[0]*100, 2)
base_model
# Out:
# 11.43

# %%
# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
accuracy
# Out:
# 0.6531845653184565

# %%
y_pred_train = model.predict(X_train_scaled)
accuracy = accuracy_score(y_train, y_pred_train)
accuracy
# Out:
# 0.6567476461699407

# %%
conf_matrix = confusion_matrix(y_test, y_pred)
conf_matrix
# Out:
# array([[235,  21,   1,   0],
#        [  2, 534, 136,  21],
#        [  0, 216, 274, 130],
#        [  1,  77, 141, 362]], dtype=int64)

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# dictionary for label names
labels = {1: "Goalkeeper", 2: "Defender", 3: "Midfield", 4: "Attack"}

# display confusion matrix
ConfusionMatrixDisplay.from_predictions(
    y_test, 
    y_pred,
    display_labels=[labels[i] for i in list(model.classes_)], 
    cmap="Blues",
    xticks_rotation='vertical'
)

# set title for the plot
plt.title('Confusion Matrix')

# show the plot
plt.show()

# %%
# Calculate Precision
precision = precision_score(y_test, y_pred, average='macro')
print(f"Precision: {precision:.2f}")
# Out:
# Precision: 0.70

# %%
# Calculate Recall
recall = recall_score(y_test, y_pred, average='macro')
print(f"Recall: {recall:.2f}")
# Out:
# Recall: 0.69

# %%
# Calculate F1 Score
f1 = f1_score(y_test, y_pred, average='macro')
print(f"F1 Score: {f1:.2f}")
# Out:
# F1 Score: 0.69
