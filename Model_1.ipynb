# %%
# To ignore warnings
import warnings
warnings.filterwarnings("ignore")
import pandas as pd
import numpy as np
import matplotlib.pyplot as pio
import seaborn as sns
import plotly.express as px
import math



from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.model_selection import GridSearchCV
from sklearn import metrics

# %matplotlib inline

# %% [markdown]
# ## Loading the data
# We can now load the dataset into pandas using the read_csv() function. This converts the CSV file into a Pandas dataframe.

# %%
df = pd.read_csv('final_data.csv')

# %%
df.shape
# Out:
# (10754, 22)

# %%
df.head(2)
# Out:
#                                 player               team          name  \
# 0   /david-de-gea/profil/spieler/59377  Manchester United  David de Gea
# 1  /jack-butland/profil/spieler/128899  Manchester United  Jack Butland
#
#      position  height   age  appearance  goals  assists  yellow cards  ...  \
# 0  Goalkeeper   189.0  32.0         104    0.0      0.0      0.009585  ...
# 1  Goalkeeper   196.0  30.0          15    0.0      0.0      0.069018  ...
#
#    goals conceded  clean sheets  minutes played  days_injured  games_injured  \
# 0        1.217252      0.335463            9390            42              5
# 1        1.242331      0.207055            1304           510             58
#
#    award  current_value  highest_value  position_encoded  winger
# 0     13       15000000       70000000                 1       0
# 1      1        1500000       22000000                 1       0
#
# [2 rows x 22 columns]

# %%
# uniqeness
df.duplicated().sum()
# Out:
# 0

# %%
# Completeness
df.isnull().sum()
# Out:
# player                 0
# team                   0
# name                   0
# position               0
# height                 0
# age                    0
# appearance             0
# goals                  0
# assists                0
# yellow cards           0
# second yellow cards    0
# red cards              0
# goals conceded         0
# clean sheets           0
# minutes played         0
# days_injured           0
# games_injured          0
# award                  0
# current_value          0
# highest_value          0
# position_encoded       0
# winger                 0
# dtype: int64

# %%
# Accurecy types
df.dtypes
# Out:
# player                  object
# team                    object
# name                    object
# position                object
# height                 float64
# age                    float64
# appearance               int64
# goals                  float64
# assists                float64
# yellow cards           float64
# second yellow cards    float64
# red cards              float64
# goals conceded         float64
# clean sheets           float64
# minutes played           int64
# days_injured             int64
# games_injured            int64
# award                    int64
# current_value            int64
# highest_value            int64
# position_encoded         int64
# winger                   int64
# dtype: object

# %%
# drop column player we dont need it 
# drop column position becuse we have position_encoded
df.drop('player',axis=1,inplace = True) 
#df.drop('position',axis=1,inplace = True) 
df.dtypes
# Out:
# team                    object
# name                    object
# position                object
# height                 float64
# age                    float64
# appearance               int64
# goals                  float64
# assists                float64
# yellow cards           float64
# second yellow cards    float64
# red cards              float64
# goals conceded         float64
# clean sheets           float64
# minutes played           int64
# days_injured             int64
# games_injured            int64
# award                    int64
# current_value            int64
# highest_value            int64
# position_encoded         int64
# winger                   int64
# dtype: object

# %%
# Accurecy - Outlier

# Convert categorical variables using OneHotEncoding
# position is alrady encoded

categorical_features = ['team']
numeric_features = ['height', 'age', 'appearance','goals', 'assists', 'yellow cards', 'second yellow cards', 'red cards',
       'goals conceded', 'clean sheets', 'minutes played', 'days_injured',
       'games_injured', 'award', 'current_value', 'highest_value',
       'position_encoded', 'winger']

# %%
for i in categorical_features:
    print (df[i].value_counts())
# Out:
# team
# Daejeon Hana Citizen      46
# Jeonbuk Hyundai Motors    46
# FC Seoul                  45
# Gangwon FC                43
# Daegu FC                  42
#                           ..
# FC Barcelona              22
# Atlético de Madrid        22
# CA Osasuna                22
# Hatayspor                 12
# Gaziantep FK               6
# Name: count, Length: 374, dtype: int64

# %%
for i in numeric_features:
    print(df[i].value_counts())
# Out:
# height
# 180.000000    744
# 185.000000    608
# 175.000000    596
# 178.000000    594
# 183.000000    572
# 188.000000    493
# 184.000000    458
# 182.000000    449
# 181.240353    440
# 186.000000    423
# 187.000000    419
# 176.000000    390
# 177.000000    372
# 190.000000    371
# 173.000000    366
# 179.000000    359
# 181.000000    355
# 170.000000    312
# 191.000000    272
# 174.000000    270
# 189.000000    255
# 172.000000    254
# 192.000000    203
# 193.000000    181
# 171.000000    169
# 168.000000    124
# 194.000000    117
# 169.000000    107
# 195.000000     98
# 167.000000     85
# 196.000000     68
# 166.000000     44
# 165.000000     42
# 197.000000     31
# 198.000000     24
# 163.000000     16
# 160.000000     15
# 164.000000     14
# 199.000000     12
# 200.000000     12
# 202.000000      6
# 162.000000      6
# 161.000000      3
# 206.000000      2
# 204.000000      1
# 156.000000      1
# 159.000000      1
# Name: count, dtype: int64
# age
# 22.000000    841
# 23.000000    823
# 26.000000    812
# 25.000000    772
# 24.000000    767
# 21.000000    715
# 28.000000    678
# 27.000000    666
# 29.000000    650
# 30.000000    617
# 20.000000    601
# 31.000000    484
# 32.000000    428
# 19.000000    411
# 33.000000    383
# 34.000000    257
# 18.000000    224
# 35.000000    177
# 36.000000    149
# 37.000000     90
# 17.000000     80
# 38.000000     36
# 39.000000     20
# 40.000000     19
# 16.000000     19
# 26.041903     15
# 42.000000      7
# 41.000000      6
# 15.000000      6
# 43.000000      1
# Name: count, dtype: int64
# appearance
# 0      389
# 1      333
# 4      225
# 17     221
# 10     216
#       ...
# 98       3
# 107      3
# 106      2
# 104      2
# 103      1
# Name: count, Length: 108, dtype: int64
# goals
# 0.000000    4354
# 1.000000      10
# 0.324910       8
# 0.400000       6
# 0.230769       6
#             ...
# 0.195652       1
# 0.334650       1
# 0.633927       1
# 0.806801       1
# 0.312139       1
# Name: count, Length: 5329, dtype: int64
# assists
# 0.000000    4539
# 0.100784       6
# 1.000000       6
# 0.174081       6
# 0.111111       6
#             ...
# 0.147589       1
# 0.176384       1
# 0.188186       1
# 0.015915       1
# 0.208333       1
# Name: count, Length: 5065, dtype: int64
# yellow cards
# 0.000000    2213
# 0.142857      16
# 0.333333      16
# 0.250000      15
# 0.125000      14
#             ...
# 0.029202       1
# 0.239203       1
# 0.154004       1
# 0.116167       1
# 0.221402       1
# Name: count, Length: 6291, dtype: int64
# second yellow cards
# 0.000000    9585
# 0.025035       3
# 0.021464       3
# 0.021388       3
# 0.036364       3
#             ...
# 0.019007       1
# 0.016657       1
# 0.065934       1
# 0.024045       1
# 0.057878       1
# Name: count, Length: 1095, dtype: int64
# red cards
# 0.000000    9423
# 0.039233       3
# 0.018572       3
# 0.018821       3
# 0.019811       3
#             ...
# 0.030685       1
# 0.016184       1
# 0.038643       1
# 0.017678       1
# 0.104046       1
# Name: count, Length: 1219, dtype: int64
# goals conceded
# 0.000000    9739
# 1.000000      36
# 2.000000      27
# 1.500000      20
# 1.333333      12
#             ...
# 1.722222       1
# 2.052632       1
# 1.493776       1
# 1.187755       1
# 1.431373       1
# Name: count, Length: 742, dtype: int64
# clean sheets
# 0.000000     9800
# 0.500000       33
# 0.333333       23
# 0.250000       19
# 1.000000       16
#              ...
# 0.410865        1
# 0.203046        1
# 10.588235       1
# 0.065598        1
# 0.254902        1
# Name: count, Length: 635, dtype: int64
# minutes played
# 0       405
# 90       98
# 180      41
# 1530     39
# 450      37
#        ...
# 1718      1
# 8411      1
# 6621      1
# 6369      1
# 820       1
# Name: count, Length: 5036, dtype: int64
# days_injured
# 0       4117
# 14        72
# 7         51
# 10        51
# 21        44
#         ...
# 622        1
# 522        1
# 525        1
# 637        1
# 1307       1
# Name: count, Length: 772, dtype: int64
# games_injured
# 0      4227
# 2       277
# 4       252
# 3       250
# 1       247
#        ...
# 201       1
# 136       1
# 169       1
# 168       1
# 146       1
# Name: count, Length: 154, dtype: int64
# award
# 0     4773
# 1     2211
# 2     1223
# 3      730
# 4      460
# 5      323
# 6      216
# 7      199
# 8      121
# 9      110
# 10      72
# 11      61
# 13      42
# 12      35
# 14      35
# 15      21
# 17      16
# 18      16
# 16      13
# 19      11
# 20      11
# 33       6
# 22       6
# 21       4
# 25       4
# 24       4
# 26       4
# 23       3
# 35       2
# 36       2
# 29       2
# 27       2
# 32       2
# 37       2
# 31       1
# 42       1
# 28       1
# 92       1
# 34       1
# 30       1
# 57       1
# 65       1
# 53       1
# 38       1
# 43       1
# 90       1
# Name: count, dtype: int64
# current_value
# 1000000      473
# 300000       456
# 500000       441
# 50000        422
# 1500000      412
#             ...
# 23000000       1
# 180000000      1
# 925000         1
# 5800000        1
# 150000000      1
# Name: count, Length: 128, dtype: int64
# highest_value
# 1000000      470
# 1500000      417
# 2000000      411
# 50000        362
# 3000000      351
#             ...
# 200000000      1
# 130000000      1
# 48000000       1
# 170000000      1
# 36500000       1
# Name: count, Length: 156, dtype: int64
# position_encoded
# 2    3528
# 3    3095
# 4    2902
# 1    1229
# Name: count, dtype: int64
# winger
# 0    7447
# 1    3307
# Name: count, dtype: int64

# %%
import math
import matplotlib.pyplot as plt
import seaborn as sns

# Define the number of numeric features
num_features = len(numeric_features)

# Calculate the number of rows and columns for the subplot grid
num_rows = math.ceil(num_features / 4)
num_cols = min(4, num_features)

# Set the figure size
plt.figure(figsize=(15, 10))

# Define a color palette (choose from seaborn built-in palettes or create your own)
color_palette = sns.color_palette("Set2")

# Loop through the numeric features and create boxplots
for i, column in enumerate(numeric_features, 1):
    plt.subplot(num_rows, num_cols, i)
    sns.boxplot(x=df[column], palette=color_palette)
    plt.title(column.capitalize())
    plt.xlabel('')

# Adjust layout
plt.tight_layout()
plt.show()

# %%
def remove_outliers_iqr(df, columns_to_analyze):
 
    df_cleaned = df.copy()
    for column in columns_to_analyze:
        if column in df_cleaned.columns:
            if pd.api.types.is_numeric_dtype(df_cleaned[column]):
                Q1 = df_cleaned[column].quantile(0.25)
                Q3 = df_cleaned[column].quantile(0.75)
                IQR = Q3 - Q1
                lower_bound = Q1 - 1.5 * IQR
                upper_bound = Q3 + 1.5 * IQR
                df_cleaned = df_cleaned[(df_cleaned[column] >= lower_bound) & (df_cleaned[column] <= upper_bound)]
            else:
                print(f"Column {column} is not numeric and will be skipped.")
        else:
            print(f"Column {column} does not exist in the DataFrame and will be skipped.")
    return df_cleaned

# %%
# Calculate the frequency of each 'Make'
make_counts = df['name'].value_counts()
make_counts
# Out:
# name
# Paulinho              6
# Vitinho               5
# Guilherme             5
# Fernando              4
# João Pedro            4
#                      ..
# Everson               1
# Matheus Mendes        1
# Gabriel Delfim        1
# Nathan Silva          1
# Alexander Badolato    1
# Name: count, Length: 10584, dtype: int64

# %%
# Create a histogram using Matplotlib
plt.figure(figsize=(10, 6))
plt.hist(df['current_value'], bins=100, edgecolor='k')
plt.title('Histogram of Current Value')
plt.xlabel('Current Value')
plt.ylabel('Frequency')

# Show the plot
plt.show()

# %%
df.head(2)
# Out:
#                 team          name    position  height   age  appearance  \
# 0  Manchester United  David de Gea  Goalkeeper   189.0  32.0         104
# 1  Manchester United  Jack Butland  Goalkeeper   196.0  30.0          15
#
#    goals  assists  yellow cards  second yellow cards  ...  goals conceded  \
# 0    0.0      0.0      0.009585                  0.0  ...        1.217252
# 1    0.0      0.0      0.069018                  0.0  ...        1.242331
#
#    clean sheets  minutes played  days_injured  games_injured  award  \
# 0      0.335463            9390            42              5     13
# 1      0.207055            1304           510             58      1
#
#    current_value  highest_value  position_encoded  winger
# 0       15000000       70000000                 1       0
# 1        1500000       22000000                 1       0
#
# [2 rows x 21 columns]

# %%
categorical_features
# Out:
# ['team']

# %%
# one hot coding
df = pd.get_dummies(df, columns=categorical_features)

# %%
df.shape
# Out:
# (10754, 394)

# %%
df.head(2)
# Out:
#            name    position  height   age  appearance  goals  assists  \
# 0  David de Gea  Goalkeeper   189.0  32.0         104    0.0      0.0
# 1  Jack Butland  Goalkeeper   196.0  30.0          15    0.0      0.0
#
#    yellow cards  second yellow cards  red cards  ...  team_West Ham United  \
# 0      0.009585                  0.0        0.0  ...                 False
# 1      0.069018                  0.0        0.0  ...                 False
#
#    team_Western Sydney Wanderers  team_Western United FC  team_Wigan Athletic  \
# 0                          False                   False                False
# 1                          False                   False                False
#
#    team_Wolfsberger AC  team_Wolverhampton Wanderers  \
# 0                False                         False
# 1                False                         False
#
#    team_Yokohama F. Marinos  team_Yokohama FC  team_Zenit St. Petersburg  \
# 0                     False             False                      False
# 1                     False             False                      False
#
#    team_Ümraniyespor
# 0              False
# 1              False
#
# [2 rows x 394 columns]

# %%
selected_features = ['appearance', 'goals', 'assists', 'minutes played', 'days_injured','games_injured', 'award', 'current_value', 'highest_value']

# %%
df = df[selected_features]
df.head()
# Out:
#    appearance     goals   assists  minutes played  days_injured  \
# 0         104  0.000000  0.000000            9390            42
# 1          15  0.000000  0.000000            1304           510
# 2           4  0.000000  0.000000             292           697
# 3          82  0.028090  0.056180            6408           175
# 4          63  0.017889  0.017889            5031           238
#
#    games_injured  award  current_value  highest_value
# 0              5     13       15000000       70000000
# 1             58      1        1500000       22000000
# 2             84      4         600000        6000000
# 3             22      9       50000000       50000000
# 4             51     21       40000000       80000000

# %%
# Prepare data
X = df.drop(['current_value'], axis=1)
y = df['current_value']

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=0.25,
                                                    shuffle=True,
                                                    random_state=42)

# sacle the data
scaler = StandardScaler()
scaler.fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
model = LinearRegression()

# %%
ridge_model = Ridge(alpha = 20)

# %%
lasso_model = Lasso(alpha = 8000)

# %%
param_grid = {
    'alpha': [2000, 3000, 4000, 4500, 6000, 7900]  # Regularization strength
}
grid_search = GridSearchCV(estimator=ridge_model,
                           param_grid=param_grid,
                           cv=5,
                           scoring='neg_mean_squared_error', 
                           verbose=1)

grid_search_lasso = GridSearchCV(estimator=lasso_model,
                           param_grid=param_grid,
                           cv=5,
                           scoring='neg_mean_squared_error', 
                           verbose=1)

# %%
# Fit the model on the training data
model.fit(X_train_scaled, y_train)
# Out:
# LinearRegression()

# %%
ridge_model.fit(X_train_scaled, y_train)
# Out:
# Ridge(alpha=20)

# %%
lasso_model.fit(X_train_scaled, y_train)
# Out:
# Lasso(alpha=8000)

# %%
grid_search.fit(X_train_scaled, y_train)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# GridSearchCV(cv=5, estimator=Ridge(alpha=20),
#              param_grid={'alpha': [2000, 3000, 4000, 4500, 6000, 7900]},
#              scoring='neg_mean_squared_error', verbose=1)

# %%
grid_search_lasso.fit(X_train_scaled, y_train)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# GridSearchCV(cv=5, estimator=Lasso(alpha=8000),
#              param_grid={'alpha': [2000, 3000, 4000, 4500, 6000, 7900]},
#              scoring='neg_mean_squared_error', verbose=1)

# %%
# Predict and evaluate the model
y_pred = model.predict(X_test_scaled)

# %%
y_pred_ridge = ridge_model.predict(X_test_scaled)

# %%
y_pred_lasso = lasso_model.predict(X_test_scaled)

# %%
# Best hyperparameter
print("Best parameters found: ", grid_search.best_params_)

# Best model
best_ridge = grid_search.best_estimator_
# Out:
# Best parameters found:  {'alpha': 2000}

# %%
# Best hyperparameter
print("Best parameters found: ", grid_search_lasso.best_params_)

# Best model
best_ridge = grid_search_lasso.best_estimator_
# Out:
# Best parameters found:  {'alpha': 4500}

# %%
y_pred_ridge_cv = best_ridge.predict(X_test_scaled)

# %%
coeff_df = pd.DataFrame(model.coef_,X.columns,columns=['Coefficient'])
coeff_df
# Out:
#                  Coefficient
# appearance     -1.207435e+06
# goals           2.116424e+05
# assists         1.913847e+05
# minutes played  2.137298e+06
# days_injured    6.398558e+05
# games_injured  -1.376379e+06
# award          -1.685619e+06
# highest_value   8.142593e+06

# %%
coeff_df = pd.DataFrame(ridge_model.coef_,X.columns,columns=['Coefficient'])
coeff_df
# Out:
#                  Coefficient
# appearance     -1.121032e+06
# goals           2.074102e+05
# assists         1.877918e+05
# minutes played  2.060948e+06
# days_injured    5.836706e+05
# games_injured  -1.316962e+06
# award          -1.666659e+06
# highest_value   8.103979e+06

# %%
coeff_df = pd.DataFrame(lasso_model.coef_,X.columns,columns=['Coefficient'])
coeff_df
# Out:
#                  Coefficient
# appearance     -1.033026e+06
# goals           1.947616e+05
# assists         1.747909e+05
# minutes played  1.971549e+06
# days_injured    4.621424e+05
# games_injured  -1.199236e+06
# award          -1.671958e+06
# highest_value   8.115947e+06

# %%
print(model.intercept_)
# Out:
# 3612928.704277743

# %%
#maby drop
y_base = [y_train.mean()] * len(y_test)

# %%
mse_base = mean_squared_error(y_test, y_base )
mse_train = mean_squared_error(y_train, model.predict(X_train_scaled))
mse_test = mean_squared_error(y_test, y_pred)
print(f'Mean Squared Error of base model: {mse_base}')
print(f'Mean Squared Error for training: {mse_train}')
print(f'Mean Squared Error for testing: {mse_test}')
# Out:
# Mean Squared Error of base model: 93659743832820.34
# Mean Squared Error for training: 20335440203143.527
# Mean Squared Error for testing: 24551462329962.094

# %%
mse_base = mean_absolute_error(y_test, y_base )
mae_train = mean_absolute_error(y_train, model.predict(X_train_scaled))
mae_test = mean_absolute_error(y_test, y_pred)
print(f'Mean Absolute  Error of base model: {mse_base}')
print(f'Mean Absolute Error for training: {mae_train}')
print(f'Mean Absolute Error for testing: {mae_test}')
# Out:
# Mean Absolute  Error of base model: 4482090.158130862
# Mean Absolute Error for training: 2103535.91875196
# Mean Absolute Error for testing: 2217592.8614085987

# %%
print(f'Root Mean Squared  Error of base model: {np.sqrt(mse_base)}')
print(f'Root Mean Squared Error for training: {np.sqrt(mse_train)}')
print(f'Root Mean Squared Error for testing: {np.sqrt(mse_test)}')
# Out:
# Root Mean Squared  Error of base model: 2117.0947447223193
# Root Mean Squared Error for training: 4509483.3632184
# Root Mean Squared Error for testing: 4954943.221668852

# %%
r2_score_train = r2_score(y_train, model.predict(X_train_scaled))
r2_score_test = r2_score(y_test, y_pred)
print(f'R Square for training: {r2_score_train}')
print(f'R Square for testing: {r2_score_test}')
# Out:
# R Square for training: 0.7428206081499305
# R Square for testing: 0.7378608552085746

# %%
predictions = model.predict(X_test_scaled)
#predictions

# %%
Real_Values = np.array(y_test)
#Real_Values

# %%
plt.figure(figsize=(8, 6))
plt.scatter(Real_Values, predictions, c='blue', alpha=0.6, edgecolors='w', linewidth=0.5)
plt.xlabel('Real Values')
plt.ylabel('Predictions')
plt.title('Real Values vs Predictions')
plt.show()

# %%
residuals = y_test - predictions

# Create the histogram with a specific color
plt.figure(figsize=(10, 6))
sns.histplot(residuals, bins=50, kde=True, color='purple')
plt.title('Distribution of Residuals')
plt.xlabel('Residuals')
plt.ylabel('Frequency')
plt.show()
